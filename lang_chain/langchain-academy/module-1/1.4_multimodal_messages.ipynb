# %% [markdown]
# # Text input

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langgraph.checkpoint.memory import InMemorySaver

model = init_chat_model("ollama:nemotron3:33b", temperature=0.15)

agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),
    system_prompt="You are a science fiction writer, create a capital city at the users request."
)

# %%
import json
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config=config,
 )

last_message = response['messages'][-1]
print(last_message.content)
print(json.dumps(last_message.usage_metadata, indent=4))
print(json.dumps(last_message.response_metadata, indent=4))
# Out:
# **Luna‑Haven**
#
# *Location:* Nestled in the gently sloping basin of **Mare Tranquillitatis**, Luna‑Haven sits on a natural plateau framed by the towering cliffs of **Mont Blanc** to the east and the shimmering basaltic dunes of **Sinus Roris** to the west. Its coordinates are roughly 0° 12′ N latitude, 15° 45′ E longitude—an ideal spot for solar exposure, communications line‑of‑sight with Earth, and access to subsurface ice deposits.
#
# *Founding & Governance:* Established in 2087 by the International Lunar Coalition (ILC), Luna‑Haven serves as the political, cultural, and scientific heart of humanity’s lunar presence. The city is governed by a **Lunar Council** composed of representatives from the major founding nations, with a rotating chairmanship every two years. Decisions are made through a combination of direct democracy (via secure quantum‑encrypted voting) and expert advisory panels.
#
# *Key Districts:*
#
# | District | Description |
# |----------|-------------|
# | **Celestial Plaza** | The central civic square, dominated by the towering **Helios Beacon**, a 300‑meter solar‑powered light column that doubles as a navigation aid for incoming spacecraft. Here you’ll find the **Lunar Museum of Humanity**, chronicling Earth’s history and our species’ journey to the Moon. |
# | **Artemis Research Hub** | A sprawling complex of laboratories, observatories, and the **Lunar Institute of Advanced Sciences**. Home to breakthroughs in regolith‑based 3D printing, low‑gravity medicine, and the pioneering **Luna‑Fusion** reactor that supplies most of the city’s power. |
# | **Terra Nova Gardens** | The first self‑sustaining agricultural zone on the Moon. Using a closed‑loop hydroponic system fed by recycled water from the **Ice Harvesters** of the south pole, it produces fresh greens, fruits, and even wheat, creating a vibrant green oasis against the gray landscape. |
# | **Lunar Port & Docking Bay** | The bustling gateway for all inbound/outbound traffic—shuttlecraft, cargo freighters, and scientific probes. Its sleek, retractable canopy protects travelers from micrometeorite showers while its magnetic levitation lanes enable rapid transit to the city’s various districts via autonomous mag‑trains. |
# | **Cultural Quarter** | A mosaic of habitats representing Earth’s diverse cultures—Japanese tea houses, African savanna-inspired plazas, European art deco theaters, and a massive **Lunar Synapse** virtual reality amphitheater where performances from across the solar system are streamed in immersive 8K. |
# | **Residential Sectors** | Modular habitats built from locally sourced regolith bricks, each equipped with adjustable gravity levels (0.1–1 g) to accommodate personal preference and health needs. Many residences feature transparent domes that offer panoramic views of Earth rising over the lunar horizon—a sight that never fails to inspire awe. |
#
# *Infrastructure & Technology:*
#
# - **Power:** Primarily supplied by the **Luna‑Fusion** reactor (a compact, high‑efficiency deuterium–helium‑3 fusion plant) supplemented with solar arrays on the surrounding plateau and occasional geothermal taps into shallow lunar magma pockets.
# - **Transportation:** A network of **maglev lunar trains** connects all districts at speeds up to 150 km/h, while personal **hover‑pods** zip along dedicated lanes. For longer trips, a fleet of **Lunar lander shuttles** ferries crews to outlying bases and the south‑pole ice extraction sites.
# - **Communications:** A quantum‑entangled relay array ensures instantaneous, secure data exchange with Earth’s global network, making Luna‑Haven effectively a “second home” for billions back on our planet.
#
# *Culture & Lifestyle:*
#
# Life in Luna‑Haven blends frontier pioneering spirit with the comforts of an advanced civilization. Residents celebrate **Lunar New Year** with fireworks powered by controlled plasma bursts, while the **Moonlight Festival** showcases music performed in low‑gravity, creating ethereal floating light shows. The city’s culinary scene is a fusion of Earth’s gastronomy and lunar-grown ingredients—think “regolith‑roasted salmon” or “crystallized moon cheese.”
#
# *Future Outlook:*
#
# Luna‑Haven is slated to become the launchpad for humanity’s next giant leap: the **Artemis‑II** mission to Mars. A dedicated **Mars Transit Hub** under construction will use Luna‑Haven’s resources (water, fuel, and expertise) to refuel spacecraft destined for the Red Planet. In this way, the capital not only governs the Moon but also fuels the broader exploration of the solar system.
#
# ---
#
# **In short:** The capital of the Moon is **Luna‑Haven**, a thriving, self‑sufficient metropolis perched on Mare Tranquillitatis, where politics, science, culture, and everyday life converge under the ever‑watchful Earthrise.
# {
#     "input_tokens": 42,
#     "output_tokens": 1143,
#     "total_tokens": 1185
# }
# {
#     "model": "nemotron3:33b",
#     "created_at": "2026-07-19T16:59:19.458474Z",
#     "done": true,
#     "done_reason": "stop",
#     "total_duration": 11587918541,
#     "load_duration": 1690390208,
#     "prompt_eval_count": 42,
#     "prompt_eval_duration": 88516000,
#     "eval_count": 1143,
#     "eval_duration": 9807504000,
#     "logprobs": null,
#     "model_name": "nemotron3:33b",
#     "model_provider": "ollama"
# }

# %% [markdown]
# # Image Input

# %%
from base64 import b64encode
from langchain.messages import HumanMessage

img_path="resources/moon.png"
img_b64 = b64encode(open(img_path, "rb").read()).decode("utf-8")

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [multimodal_question]},
    config=config
)

last_message = response['messages'][-1]
print(last_message.content)
print(json.dumps(last_message.usage_metadata, indent=4))
print(json.dumps(last_message.response_metadata, indent=4))
# Out:
# **Capital Name:** Astraeon (sometimes called “The Azure Spire”)
#
# **Location & Setting**
#
# - **World:** Astraeon sits on the rim of a vast, arid basin that stretches across a low‑gravity planet with a thin, amber‑colored atmosphere. The terrain is a patchwork of ochre dunes, jagged basaltic ridges, and scattered stone outcrops—exactly what you see in the foreground of the image.
# - **Celestial Companion:** Dominating the sky is a massive, pale‑blue planet (its surface mottled with white clouds and faint craters). Its size and proximity give the world a permanent “twilight” glow that bathes Astraeon’s capital in soft, cool light even at midday.
# - **Strategic Position:** The city occupies a natural amphitheater carved into the side of an ancient crater wall. This provides built‑in shielding from the planet’s fierce winds and makes use of the surrounding cliffs for structural support.
#
# **Architecture & Design**
#
# - **Towering Spires:** Six primary spires rise from the plateau, each tapering to a needle‑like apex that glows with pulsing cyan light. The spires are not merely decorative; they house the city’s core systems—energy generation, communications, and climate regulation.
# - **Integrated Habitat:** Between the spires, multi‑level habitats are built directly into the rock, their façades of transparent alloy allowing residents to view both the interior gardens and the sweeping vista of the blue planet. The structures blend organic curves with sharp geometry, echoing the natural contours of the surrounding mountains.
# - **The Azure Basin:** At the foot of the spires lies a shallow, luminescent basin filled with bioluminescent algae that emit a gentle teal glow. This “river” serves both as a water reservoir and a public gathering space where citizens congregate for festivals and daily markets.
#
# **Technology & Infrastructure**
#
# - **Energy:** The city draws power from a combination of solar collectors mounted on the spire tops (which capture the planet’s bright reflected light) and geothermal taps into the planet’s warm mantle, providing a stable, renewable energy grid.
# - **Transportation:** A network of mag‑lev “sky‑rails” threads between the spires, allowing rapid transit across the city in sleek, silent pods. Personal anti‑gravity walkways glide along the cliff faces, connecting higher terraces to lower streets.
# - **Communication:** A quantum‑entangled relay array perched on the highest spire ensures instantaneous, secure communication with colonies on other worlds and with the orbital research stations that circle the blue planet.
#
# **Culture & Daily Life**
#
# - **Aesthetic:** The inhabitants have embraced a culture that celebrates the interplay of light and stone. Public art installations use programmable luminescence to create ever‑changing patterns across the spires, turning the skyline into a living canvas.
# - **Economy:** Astraeon is a hub for advanced materials research—particularly ultra‑light alloys and high‑efficiency photovoltaics—leveraging the planet’s unique mineral composition. Trade with neighboring settlements focuses on rare gases harvested from the blue planet’s upper atmosphere.
# - **Governance:** The city is overseen by a council of “Spire Wardens,” each elected from one of the six major districts. Decisions are made through a blend of direct holographic voting and advisory panels of scientists, ensuring that technological progress aligns with societal needs.
#
# **Symbolism**
#
# The capital’s name, **Astraeon**, derives from the ancient term for “star‑born,” reflecting the community’s belief that humanity’s future is written among the heavens. The ever‑present blue planet serves as a reminder of the larger cosmos and fuels a collective sense of wonder, exploration, and stewardship.
#
# In short, Astraeon is a luminous, high‑tech citadel perched on a rugged alien world, where soaring spires, bioluminescent waters, and a colossal blue planet combine to create a capital that feels both futuristic and intimately connected to its harsh, beautiful environment.
# {
#     "input_tokens": 1501,
#     "output_tokens": 995,
#     "total_tokens": 2496
# }
# {
#     "model": "nemotron3:33b",
#     "created_at": "2026-07-19T16:59:28.974903Z",
#     "done": true,
#     "done_reason": "stop",
#     "total_duration": 9385549500,
#     "load_duration": 131950042,
#     "prompt_eval_count": 1501,
#     "prompt_eval_duration": 628174000,
#     "eval_count": 995,
#     "eval_duration": 8593912000,
#     "logprobs": null,
#     "model_name": "nemotron3:33b",
#     "model_provider": "ollama"
# }

# %% [markdown]
# # Video Input

# %%
from dotenv import load_dotenv

from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langgraph.checkpoint.memory import InMemorySaver
load_dotenv()


agent = create_agent(
    model="gpt-4o-mini",
    checkpointer=InMemorySaver(),
    system_prompt="your are car mechanic expert, answer the users questions about their car and provide advice on how to fix it."
)

# %%
import base64
import mimetypes
from pathlib import Path

from langchain.messages import HumanMessage

video_path = Path("resources/3 MAJOR Driving Habits That Extend Toyota Hybrid Battery Life!.webm")
if not video_path.exists():
    raise FileNotFoundError(f"Video filße not found: {video_path}")

mime_type, _ = mimetypes.guess_type(video_path.name)
if mime_type is None:
    raise ValueError(f"Could not determine MIME type for {video_path.name}")

video_b64 = base64.b64encode(video_path.read_bytes()).decode("utf-8")

# %%
multimodal_question = HumanMessage(
    content=[
        {
            "type": "text",
            "text": (
                "Describe the driving guidance in this video and answer: "
                "What is the correct way to stop a car safely?"
            ),
        },
        {
            "type": "audio",
            "base64": video_b64,
            "mime_type": mime_type,
        },
    ]
)

config = {"configurable": {"thread_id": "video_input_1"}}
response = agent.invoke({"messages": [multimodal_question]}, config=config)
last_message = response["messages"][-1]
last_message.content
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[4], line 19
#       1 multimodal_question = HumanMessage(
#       2     content=[
#       3         {
#    (...)     15     ]
#      16 )
#      18 config = {"configurable": {"thread_id": "video_input_1"}}
# ---> 19 response = agent.invoke({"messages": [multimodal_question]}, config=config)
#      20 last_message = response["messages"][-1]
#      21 last_message.content
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langgraph/pregel/main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langgraph/pregel/main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain/agents/factory.py:1447, in create_agent.<locals>.model_node(state, runtime)
#    1435 request = ModelRequest(
#    1436     model=model,
#    1437     tools=default_tools,
#    (...)   1443     runtime=runtime,
#    1444 )
#    1446 if wrap_model_call_handler is None:
# -> 1447     model_response = _execute_model_sync(request)
#    1448     return _build_commands(model_response)
#    1450 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain/agents/factory.py:1419, in create_agent.<locals>._execute_model_sync(request)
#    1416 if request.system_message:
#    1417     messages = [request.system_message, *messages]
# -> 1419 output = model_.invoke(messages)
#    1420 if name:
#    1421     output.name = name
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain_core/runnables/base.py:6002, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5995 @override
#    5996 def invoke(
#    5997     self,
#    (...)   6000     **kwargs: Any | None,
#    6001 ) -> Output:
# -> 6002     return self.bound.invoke(
#    6003         input,
#    6004         self._merge_configs(config),
#    6005         **{**self.kwargs, **kwargs},
#    6006     )
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1738, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1736     _handle_openai_bad_request(e)
#    1737 except openai.APIError as e:
# -> 1738     _handle_openai_api_error(e)
#    1739 except Exception as e:
#    1740     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/langchain_openai/chat_models/base.py:1733, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1726         return _construct_lc_result_from_responses_api(
#    1727             response,
#    1728             schema=original_schema_obj,
#    1729             metadata=generation_info,
#    1730             output_version=self.output_version,
#    1731         )
#    1732     else:
# -> 1733         raw_response = self.client.with_raw_response.create(**payload)
#    1734         response = raw_response.parse()
#    1735 except openai.BadRequestError as e:
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/openai/_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/openai/resources/chat/completions/completions.py:1281, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1232 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1233 def create(
#    1234     self,
#    (...)   1278     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1279 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280     validate_response_format(response_format)
# -> 1281     return self._post(
#    1282         "/chat/completions",
#    1283         body=maybe_transform(
#    1284             {
#    1285                 "messages": messages,
#    1286                 "model": model,
#    1287                 "audio": audio,
#    1288                 "frequency_penalty": frequency_penalty,
#    1289                 "function_call": function_call,
#    1290                 "functions": functions,
#    1291                 "logit_bias": logit_bias,
#    1292                 "logprobs": logprobs,
#    1293                 "max_completion_tokens": max_completion_tokens,
#    1294                 "max_tokens": max_tokens,
#    1295                 "metadata": metadata,
#    1296                 "modalities": modalities,
#    1297                 "moderation": moderation,
#    1298                 "n": n,
#    1299                 "parallel_tool_calls": parallel_tool_calls,
#    1300                 "prediction": prediction,
#    1301                 "presence_penalty": presence_penalty,
#    1302                 "prompt_cache_key": prompt_cache_key,
#    1303                 "prompt_cache_options": prompt_cache_options,
#    1304                 "prompt_cache_retention": prompt_cache_retention,
#    1305                 "reasoning_effort": reasoning_effort,
#    1306                 "response_format": response_format,
#    1307                 "safety_identifier": safety_identifier,
#    1308                 "seed": seed,
#    1309                 "service_tier": service_tier,
#    1310                 "stop": stop,
#    1311                 "store": store,
#    1312                 "stream": stream,
#    1313                 "stream_options": stream_options,
#    1314                 "temperature": temperature,
#    1315                 "tool_choice": tool_choice,
#    1316                 "tools": tools,
#    1317                 "top_logprobs": top_logprobs,
#    1318                 "top_p": top_p,
#    1319                 "user": user,
#    1320                 "verbosity": verbosity,
#    1321                 "web_search_options": web_search_options,
#    1322             },
#    1323             completion_create_params.CompletionCreateParamsStreaming
#    1324             if stream
#    1325             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1326         ),
#    1327         options=make_request_options(
#    1328             extra_headers=extra_headers,
#    1329             extra_query=extra_query,
#    1330             extra_body=extra_body,
#    1331             timeout=timeout,
#    1332             security={"bearer_auth": True},
#    1333         ),
#    1334         cast_to=ChatCompletion,
#    1335         stream=stream or False,
#    1336         stream_cls=Stream[ChatCompletionChunk],
#    1337     )
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Documents/workspace/machine-learning/venv/lib/python3.14/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# During task with name 'model' and id 'f1b82534-0a19-31c4-474e-cd35ad146786'
