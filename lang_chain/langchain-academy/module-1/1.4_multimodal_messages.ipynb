# %% [markdown]
# # Text input

# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langgraph.checkpoint.memory import InMemorySaver

model = init_chat_model("ollama:nemotron3:33b", temperature=0.15)

agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),
    system_prompt="You are a science fiction writer, create a capital city at the users request."
)

# %%
import json
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config=config,
 )

last_message = response['messages'][-1]
print(last_message.content)
print(json.dumps(last_message.usage_metadata, indent=4))
print(json.dumps(last_message.response_metadata, indent=4))
# Out:
# **Capital City: Lunara**
#
# *Location & Setting*
# - **Site:** Nestled in the gently sloping basin of **Mare Tranquillitatis**, just a few kilometers east of the historic landing site of Apollo 11. The basin’s relatively flat terrain, abundant solar exposure, and nearby water‑ice deposits make it ideal for large‑scale habitation.
# - **Elevation:** About 2 km below the lunar “sea level” (the mean radius of the Moon), giving Lunara a shallow gravity well that eases construction while still retaining enough pull to keep structures stable.
#
# *City Layout*
# 1. **The Core – The Selenite Plaza**
#    - A vast, domed public square built from transparent lunar glass (a silica‑based material harvested from the regolith). At its heart stands the **Lunar Beacon**, a 300‑meter tall spire of polished moonstone that houses the city’s central AI—*Selene*—which coordinates everything from traffic flow to environmental regulation.
# 2. **The Habitat Rings**
#    - Concentric, modular habitats radiate outward like rings on a record. Each ring is a self‑contained “city‑within‑a‑city,” featuring:
#      * **Pressurized biomes** with hydroponic farms that grow lettuce, wheat, and algae under artificial sunlight.
#      * **Living quarters** built from 3D‑printed regolith bricks reinforced with carbon nanotube mesh, giving them a sleek, metallic sheen.
#      * **Recreation zones**—low‑gravity parks where children play in floating ballrooms and athletes practice lunar parkour.
# 3. **The Trade & Industry Belt**
#    - A 5‑km wide strip encircling the habitat rings, home to:
#      * **Regolith refineries** that extract oxygen, silicon, and rare earths for both local use and export.
#      * **Space‑port facilities** with launch pads for Earth‑shuttlecraft and deep‑space vessels; the most active launch corridor is called “The Silver Arrow.”
# 4. **The Cultural Quarter – Artemis Heights**
#    - A collection of museums, theaters, and galleries celebrating humanity’s lunar heritage. Highlights include:
#      * The **Apollo Archive**, a holographic museum that recreates historic moonwalks.
#      * The **Lunar Symphony Hall**, where performances are staged in a vacuum‑adapted acoustic chamber, using resonant vibrations of the regolith itself.
#
# *Governance*
# - Lunara is the administrative capital of the **International Lunar Federation (ILF)**, a body composed of representatives from all Moon‑based nations and private enterprises. The city’s mayor is elected every five Earth years by a weighted vote: each nation gets one vote, while major corporations (e.g., lunar mining conglomerates) receive additional votes proportional to their contribution to the city’s life‑support and economic output.
# - **Selene**, the central AI, runs the day‑to‑day services—air revitalization, power distribution, traffic management—but ultimate decisions are made by the **Lunar Council**, a human deliberative assembly that meets in the Selenite Plaza’s Hall of Mirrors.
#
# *Culture & Daily Life*
# - **Low‑Gravity Recreation:** Residents enjoy “float festivals” where lanterns drift lazily in the Moon’s gentle 1/6th gravity, and nighttime is illuminated by a spectacular aurora created by engineered plasma ribbons orbiting just above the city.
# - **Cuisine:** Meals are a blend of Earth‑grown produce and lunar‑harvested delicacies—crystallized moon‑salted fish, algae‑based “moon cheese,” and the iconic **regolith ramen**, whose noodles are infused with trace minerals that give them a subtle metallic sheen.
# - **Language:** A hybrid lingua‑lunar has emerged, mixing English, Mandarin, Arabic, and technical jargon from space engineering; most signs are bilingual (English + Lunar Symbols) for clarity.
#
# *Why It Works as a Capital*
# 1. **Strategic Position:** Its location in Mare Tranquillitatis offers easy access to the majority of lunar resources while keeping radiation exposure low thanks to surrounding basaltic hills that act as natural shielding.
# 2. **Economic Hub:** The combination of research labs, manufacturing facilities, and a space‑port makes Lunara the focal point for both scientific advancement and interplanetary trade.
# 3. **Symbolic Power:** As the site where humanity first set foot on another world, Lunara carries deep historic and emotional weight—perfect for a capital that represents unity across nations and generations.
#
# **In short:** The Moon’s capital isn’t a nation‑state in the traditional sense; it is **Lunara**, a meticulously engineered, culturally vibrant city that serves as the political heart and economic engine of all lunar activity. It stands as humanity’s first true off‑world metropolis—a beacon of cooperation, innovation, and the endless possibility that lies beyond Earth’s horizon.
# {
#     "input_tokens": 42,
#     "output_tokens": 1253,
#     "total_tokens": 1295
# }
# {
#     "model": "nemotron3:33b",
#     "created_at": "2026-07-10T16:13:58.814231Z",
#     "done": true,
#     "done_reason": "stop",
#     "total_duration": 13421182208,
#     "load_duration": 2208558125,
#     "prompt_eval_count": 42,
#     "prompt_eval_duration": 375336000,
#     "eval_count": 1253,
#     "eval_duration": 10835250000,
#     "logprobs": null,
#     "model_name": "nemotron3:33b",
#     "model_provider": "ollama"
# }

# %% [markdown]
# # Image Input

# %%
from base64 import b64encode
from langchain.messages import HumanMessage

img_path="resources/moon.png"
img_b64 = b64encode(open(img_path, "rb").read()).decode("utf-8")

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [multimodal_question]},
    config=config
)

last_message = response['messages'][-1]
print(last_message.content)
print(json.dumps(last_message.usage_metadata, indent=4))
print(json.dumps(last_message.response_metadata, indent=4))
# Out:
# **Capital City:** **Astraeon**
#
# **Location & Setting**
# - **Planet:** The capital sits on the arid world of **Kryos‑9**, a moon‑like body orbiting the gas giant **Vespera**. Vespera dominates the sky, appearing as a massive, pale‑blue sphere with faint cloud bands and a subtle glow from reflected starlight.
# - **Terrain:** Astraeon rises from a sea of ochre dunes and jagged basaltic ridges that stretch for dozens of kilometres. The city is perched on a natural plateau where the ground breaks into shallow basins that collect occasional melt‑water, giving rise to thin, luminescent pools (the “blue veins” seen in the foreground).
# - **Climate:** Daytime temperatures soar above 45 °C, but the thin atmosphere and high albedo of the surrounding rocks keep night‑time lows near –20 °C. The city’s structures are equipped with active thermal regulation and solar‑shielding domes.
#
# **Architecture & Urban Layout**
# 1. **The Spires of Dawn** – A cluster of six towering megastructures, each 800 m tall, made from a composite of carbon‑nanotube lattice and translucent “sky‑glass.” Their façades pulse with teal light that syncs to the planet’s orbital period, creating a rhythmic beacon visible across the desert.
# 2. **The Confluence Plaza** – A vast, open amphitheatre carved into the plateau, surrounded by low‑profile habitats. Holographic ribbons of data flow above the plaza, displaying real‑time planetary maps, trade statistics, and cultural performances.
# 3. **The Oasis District** – Built around the natural blue pools, this zone houses hydroponic farms, water‑reclamation plants, and residential pods that benefit from the micro‑climate created by the evaporating water. The pools are illuminated by bioluminescent algae cultivated in transparent tanks.
# 4. **The Archive Spire** – A solitary, slender tower at the city’s far edge, its surface etched with the histories of Kryos‑9’s settlement. It serves as a repository for interstellar knowledge and a communication hub linking the colony to the broader Vespera system.
#
# **Governance**
# - **Council of the Horizon:** A 12‑member body elected from the major occupational guilds (Science & Exploration, Resource Extraction, Energy & Infrastructure, Culture & Arts, Defense & Security, and the Commercial Consortium, plus three representatives from the indigenous “Sirocco” nomadic clans).
# - **AI Steward “Lumen”:** An autonomous management system that monitors environmental controls, energy distribution, and public services. Lumen operates under a charter of transparency; its decisions are reviewed by the Council on a monthly cycle.
#
# **Economy & Industry**
# - **Resource Extraction:** Mining operations harvest rare earths, helium‑3, and exotic silicates from the surrounding basalt cliffs. The extracted materials feed both local manufacturing and export to colonies in the inner system.
# - **Energy Production:** Massive solar arrays line the plateau’s edges, while a geothermal plant taps into residual heat from ancient volcanic activity beneath the desert floor. Excess energy is beamed via microwave relays to orbiting habitats around Vespera.
# - **High‑Tech Manufacturing:** The city’s spires host factories that produce advanced alloys, quantum‑computing components, and autonomous exploration drones used for deep‑space missions.
#
# **Culture & Daily Life**
# - **Festival of the Blue Moon:** Once every orbital cycle of Vespera (≈ 18 Earth months), citizens gather in the Confluence Plaza to watch a spectacular light show where the planet’s reflected sunlight is refracted through the city’s sky‑glass, painting the desert in shifting shades of azure.
# - **Art & Music:** The low gravity and thin air lend themselves to “aural levitation” performances—sound waves are amplified using resonant crystal chambers embedded in the spires, creating immersive, three‑dimensional music experiences.
# - **Cuisine:** Meals blend Earth‑grown hydroponic vegetables with locally sourced desert fungi and protein derived from cultured insect farms. A signature dish is “Blue‑Vein Stew,” a broth infused with minerals that give it a faint cerulean hue.
#
# **Strategic Importance**
# - **Gateway to the Outer System:** Astraeon’s orbital docks serve as the primary launch point for vessels heading toward the gas giant’s moons and the asteroid belts beyond. Its position makes it a critical hub for interplanetary trade routes.
# - **Scientific Outpost:** The city hosts the **Kryos‑9 Planetary Research Institute**, where scientists study the unique geology of the desert world, the atmospheric dynamics of Vespera, and the potential for terraforming exoplanetary environments.
#
# **Why Astraeon Stands Out**
# The visual contrast—ancient, barren terrain against sleek, luminous towers under a gigantic blue planet—embodies humanity’s drive to carve civilization out of harsh worlds. Its blend of high‑tech infrastructure, sustainable resource management, and deep cultural traditions makes it not just a political capital, but a living testament to what a post‑Earth civilization can achieve when it embraces both its technological ingenuity and its connection to the alien environment that surrounds it.
# {
#     "input_tokens": 1472,
#     "output_tokens": 1229,
#     "total_tokens": 2701
# }
# {
#     "model": "nemotron3:33b",
#     "created_at": "2026-07-10T16:18:47.61802Z",
#     "done": true,
#     "done_reason": "stop",
#     "total_duration": 11712711625,
#     "load_duration": 122628333,
#     "prompt_eval_count": 1472,
#     "prompt_eval_duration": 865139000,
#     "eval_count": 1229,
#     "eval_duration": 10694773000,
#     "logprobs": null,
#     "model_name": "nemotron3:33b",
#     "model_provider": "ollama"
# }

# %% [markdown]
# # Audio Input
